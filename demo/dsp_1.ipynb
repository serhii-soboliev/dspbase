# %%
import numpy as np
import matplotlib.pyplot as plt
from com.sbk.dspbase.dft import dft, i_dft

# %%
SN = 100000
st = np.arange(start=0, stop=SN, step=0.03)
N = 64
F = 10

t = st[0:N-1]
x = 2*np.sin(F*t)
plt.plot(x)
plt.show()

# %%
re_x, im_x = dft(x)
plt.plot(re_x)
plt.show()

# %%
from com.sbk.dspbase.dft import i_dft

x_restored = i_dft(re_x, im_x)
plt.plot(x_restored)
plt.show()
