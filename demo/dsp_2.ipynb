# %%
import numpy as np
import matplotlib.pyplot as plt
from com.sbk.dspbase.dft import dft, i_dft

# %%
N = 32
x = np.zeros(N)
x[0] = 32

plt.stem(x)
plt.show()

# %%
re_x, im_x = dft(x)
plt.stem(re_x)
plt.show()

# %%
x_renewed = i_dft(re_x, im_x)
plt.stem(x_renewed)
plt.show()
