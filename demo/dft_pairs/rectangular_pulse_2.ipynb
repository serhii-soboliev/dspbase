# %%
import numpy as np
import matplotlib.pyplot as plt
from com.sbk.dspbase.dft import dft, i_dft

# %%
N = 512
x = np.zeros(N)
x[10:18] = 32

# %%
plt.plot(x)
plt.show()

# %%
re, im = dft(x)
plt.plot(re)
plt.show()

# %%
plt.stem(im)
plt.show()

# %%
x_restored = i_dft(re, im)
plt.plot(x_restored)
plt.show()
