# %%
import numpy as np
import matplotlib.pyplot as plt
from com.sbk.dspbase.dft import dft, i_dft

# %%
N = 128
x = np.zeros(N)
x[50:65] = 32

# %%
plt.plot(x)
plt.show()

# %%
re, im = dft(x)
plt.plot(re)
plt.show()

# %%
plt.stem(im)
plt.show()
