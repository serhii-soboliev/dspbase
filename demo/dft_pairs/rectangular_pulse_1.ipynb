# %%
import numpy as np
import matplotlib.pyplot as plt
from com.sbk.dspbase.dft import dft, i_dft
from com.sbk.dspbase.polar import cart_to_polar
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-f3a999669bca> in <module>()
#       1 import numpy as np
# ----> 2 import matplotlib.pyplot as plt
#       3 from com.sbk.dspbase.dft import dft, i_dft
#       4 from com.sbk.dspbase.polar import cart_to_polar
#
# C:\Users\ssob\PycharmProjects\dspbase\venv\lib\site-packages\matplotlib\__init__.py in <module>()
#     126     _backports, mplDeprecation, dedent, get_label, sanitize_sequence)
#     127 from matplotlib.compat import subprocess
# --> 128 from matplotlib.rcsetup import defaultParams, validate_backend, cycler
#     129
#     130 import numpy
#
# C:\Users\ssob\AppData\Local\Programs\Python\Python36\lib\importlib\_bootstrap.py in _find_and_load(name, import_)
#
# C:\Users\ssob\AppData\Local\Programs\Python\Python36\lib\importlib\_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# C:\Users\ssob\AppData\Local\Programs\Python\Python36\lib\importlib\_bootstrap.py in _load_unlocked(spec)
#
# C:\Users\ssob\AppData\Local\Programs\Python\Python36\lib\importlib\_bootstrap_external.py in exec_module(self, module)
#
# C:\Users\ssob\AppData\Local\Programs\Python\Python36\lib\importlib\_bootstrap_external.py in get_code(self, fullname)
#
# C:\Users\ssob\AppData\Local\Programs\Python\Python36\lib\importlib\_bootstrap_external.py in _compile_bytecode(data, name, bytecode_path, source_path)
#
# ValueError: bad marshal data (unknown type code)

# %%
N = 128
x = np.zeros(N)
x[0:7] = 32
x[-8:-1] = 32

# %%
plt.plot(x)
plt.show()

# %%
re, im = dft(x)
plt.plot(re)
plt.show()

# %%
ro, phi = cart_to_polar(re, im)
plt.plot(ro)
plt.show()

# %%
plt.plot(phi)
plt.show()
